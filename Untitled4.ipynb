# %%
import pandas as pd
df = pd.read_csv('/home/wojciech/Pulpit/4/kliki_uczenie2.csv', nrows=100000)
df.head()
# Out:
#    Unnamed: 0  klik  CYF_baner_pozycja  CYF_strona_id  CYF_strona_domena  \
# 0           0     0                  0           1773               3205
# 1           1     0                  0            406               3944
# 2           2     0                  0           1156               3252
# 3           3     0                  1           2948               2050
# 4           4     0                  0           1773               3205
#
#    CYF_strona_kategoria  CYF_aplikacja_id  CYF_aplikacja_domena  \
# 0                     6              4718                   134
# 1                     2              4353                   123
# 2                     4              4353                   123
# 3                    22              4353                   123
# 4                     6              1066                    36
#
#    CYF_aplikacja_kategoria  CYF_urz_id  ...  CYF_KL1_kat7  NZS1  NZS2  NZS3  \
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0                       int64
# klik                             int64
# CYF_baner_pozycja                int64
# CYF_strona_id                    int64
# CYF_strona_domena                int64
# CYF_strona_kategoria             int64
# CYF_aplikacja_id                 int64
# CYF_aplikacja_domena             int64
# CYF_aplikacja_kategoria          int64
# CYF_urz_id                       int64
# CYF_urz_ip                       int64
# CYF_urz_model                    int64
# CYF_urz_typ                      int64
# CYF_urz_polaczenie               int64
# CYF_kat1                         int64
# CYF_kat2                         int64
# CYF_kat3                         int64
# CYF_kat4                         int64
# CYF_kat5                         int64
# CYF_kat6                         int64
# CYF_kat7                         int64
# CYF_kat8                         int64
# CYF_kat9                         int64
# CYF_data_godzina                 int64
# ...

# %%
import seaborn as sns

sns.lmplot(data=df, x='CYF_kat6', y='CYF_kat4',fit_reg=False, hue='klik')

# %%
sns.jointplot(x='NZS8', y='CYF_strona_kategoria', data=df)

# %%
sns.pairplot(data=df[['CYF_kat6' ,'CYF_kat1','CYF_kat2', 'klik']], hue='klik', dropna=True, height=2)
# Out:
# /home/wojciech/anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# /home/wojciech/anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
import matplotlib.pyplot as plt

g = sns.PairGrid(data=df[['CYF_kat6' ,'CYF_kat1','CYF_kat2', 'klik']], hue='klik', dropna=True, height=2)
g = g.map_upper(plt.scatter)
g = g.map_lower(sns.kdeplot)
g = g.map_diag(sns.kdeplot, lw=2)
g.fig.legend(labels=labels, loc='upper left', ncol=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-8d96809ca105> in <module>
#       5 g = g.map_lower(sns.kdeplot)
#       6 g = g.map_diag(sns.kdeplot, lw=2)
# ----> 7 g.fig.legend(labels=labels, loc='upper left', ncol=1)
#
# NameError: name 'labels' is not defined
